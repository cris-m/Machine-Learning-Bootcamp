# %% [markdown]
# # Plotly and Cufflinks
# create interactive visualization

# %%
import pandas as pd
import numpy as np
from plotly import __version__
# %matplotlib inline

# %%
print(__version__)
# Out:
# 4.8.2

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot # we gonna host our plot offline

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# get data
df1 = pd.DataFrame(np.random.randn(100,4), columns = 'A B C D'.split())

# %%
df1.head()
# Out:
#           A         B         C         D
# 0 -0.108240  0.367225 -0.468101 -0.693141
# 1  1.323396  0.879562 -1.346227 -1.433707
# 2  0.049117 -1.167348 -0.480305  0.166948
# 3  1.101522  1.231385 -1.105799  1.129721
# 4 -0.505845 -1.002873 -0.114049  0.484499

# %%
df2 = pd.DataFrame({'Category':['A', 'B', 'C'], 'Value': [32, 43, 50]})

# %%
df2
# Out:
#   Category  Value
# 0        A     32
# 1        B     43
# 2        C     50

# %%
# plot
df1.iplot()
# Out:
# <div>
#
#
#             <div id="c5f2a611-225b-4536-bb4c-b967cb3466f8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c5f2a611-225b-4536-bb4c-b967cb3466f8")) {
#                     Plotly.newPlot(
#                         'c5f2a611-225b-4536-bb4c-b967cb3466f8',
# ...

# %%
# scatter plot
df1.iplot(kind='scatter', x='A', y='B', mode='markers', size=10)
# Out:
# <div>
#
#
#             <div id="20079b4c-273a-46e3-bd7f-f694575767e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("20079b4c-273a-46e3-bd7f-f694575767e3")) {
#                     Plotly.newPlot(
#                         '20079b4c-273a-46e3-bd7f-f694575767e3',
# ...

# %%
# bar plot
df2.iplot(kind='bar', x='Category', y='Value')
# Out:
# <div>
#
#
#             <div id="660112af-a0bb-4727-9710-561654e0d665" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("660112af-a0bb-4727-9710-561654e0d665")) {
#                     Plotly.newPlot(
#                         '660112af-a0bb-4727-9710-561654e0d665',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Value", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C"], "y": [32, 43, 50]}],
# ...

# %%
#df1.count().iplot(kind='bar') you can call any aggregate function
df1.sum().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="57d8723c-9de6-4fbb-a1e9-6a054edab549" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("57d8723c-9de6-4fbb-a1e9-6a054edab549")) {
#                     Plotly.newPlot(
#                         '57d8723c-9de6-4fbb-a1e9-6a054edab549',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "x": ["A", "B", "C", "D"], "y": [11.177231615404136, -4.878859679981188, -5.167009339834888, 9.62451306007717]}],
# ...

# %%
# box plot
df1.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="650c028e-5670-4ecf-8460-8396cd995111" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("650c028e-5670-4ecf-8460-8396cd995111")) {
#                     Plotly.newPlot(
#                         '650c028e-5670-4ecf-8460-8396cd995111',
# ...

# %%
# 3D surface plot
df3 = pd.DataFrame({'x':[1, 2, 3, 4, 5], 'y': [10, 20, 30, 20, 10], 'z': [5, 4, 3, 2, 1]})

# %%
df3
# Out:
#    x   y  z
# 0  1  10  5
# 1  2  20  4
# 2  3  30  3
# 3  4  20  2
# 4  5  10  1

# %%
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="d46bf48e-b5bf-475a-9d3b-cd90fdedb49d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d46bf48e-b5bf-475a-9d3b-cd90fdedb49d")) {
#                     Plotly.newPlot(
#                         'd46bf48e-b5bf-475a-9d3b-cd90fdedb49d',
# ...

# %%
# histogramme
df1['A'].iplot(kind='hist', bins=50)
# Out:
# <div>
#
#
#             <div id="c4ffcefb-4c41-4a10-b482-4a4dc9477a54" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c4ffcefb-4c41-4a10-b482-4a4dc9477a54")) {
#                     Plotly.newPlot(
#                         'c4ffcefb-4c41-4a10-b482-4a4dc9477a54',
# ...

# %%
# spread plot
df1[['A', 'B']].iplot(kind='spread')
# Out:
# C:\Users\cris_0XC0\anaconda3\lib\site-packages\cufflinks\plotlytools.py:849: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#
# C:\Users\cris_0XC0\anaconda3\lib\site-packages\cufflinks\plotlytools.py:850: FutureWarning:
#
# The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
# <div>
#
#
#             <div id="5c525fae-8fed-458f-9619-76848e948b53" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5c525fae-8fed-458f-9619-76848e948b53")) {
#                     Plotly.newPlot(
# ...

# %%
# bubble plot
df1.iplot(kind='bubble', x='A', y='B', size='C')
# Out:
# <div>
#
#
#             <div id="52f745bb-b0d8-4b6c-9387-fe6de8679a81" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("52f745bb-b0d8-4b6c-9387-fe6de8679a81")) {
#                     Plotly.newPlot(
#                         '52f745bb-b0d8-4b6c-9387-fe6de8679a81',
# ...

# %%
# scatter metric plot
df.scatter_matrix()
# Out:
# <div>
#
#
#             <div id="3a9f1dc4-0505-48a7-9a3f-1ffbaeeb823e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("3a9f1dc4-0505-48a7-9a3f-1ffbaeeb823e")) {
#                     Plotly.newPlot(
#                         '3a9f1dc4-0505-48a7-9a3f-1ffbaeeb823e',
# ...

# %%
# area plot
df1.iplot(kind='area', fill=True,opacity=1)
# Out:
# <div>
#
#
#             <div id="2178aa16-c5e4-4385-bd20-a65a1881cf2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("2178aa16-c5e4-4385-bd20-a65a1881cf2c")) {
#                     Plotly.newPlot(
#                         '2178aa16-c5e4-4385-bd20-a65a1881cf2c',
# ...
